# %% [markdown]
# # Real Time Visual Tracking with RRN

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
import glob
import cv2
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil

# %%
#shutil.unpack_archive("/content/drive/MyDrive/Deep Learning - Fall 22'/Final Project/Code/Dataset_Sequential.zip", "Dataset_Sequential")

# %% [markdown]
# ## METHODS

# %%
def data_loader(num_imgs, path): 
  image_list_all = []
  for i in range(num_imgs): 
    image_list_all.append(np.asarray(Image.open((path + str(i) + ".jpeg"))).astype('float32')/255)
  
  data = np.asarray(image_list_all)
  del image_list_all

  labels = pd.read_csv(path + "detection_boxes.csv")
  labels = np.asarray(labels)
  labels = labels[:num_imgs, 1:]
  
  # Data Normalization
  data = (data.reshape(num_imgs, -1) - np.mean(data)) / np.std(data)
  labels = labels.reshape(num_imgs, -1) / img_size

  x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size = 0.2)
  del data, labels

  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.25)

  return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def IOU(bbox1, bbox2):
  """
  Calculate overlap between two bounding boxes [x, y, w, h] as the area of intersection over the area of unity
  
  """
  # Predicted Block
  x1 = bbox1[0]
  y1 = bbox1[3]
  w1 = bbox1[2] - bbox1[0]
  h1 = bbox1[1] - bbox1[3]

  # Real Block
  x2 = bbox2[0]
  y2 = bbox2[3]
  w2 = bbox2[2] - bbox2[0]
  h2 = bbox2[1] - bbox2[3]

  w_I = min(x1 + w1, x2 + w2) - max(x1, x2)
  h_I = min(y1 + h1, y2 + h2) - max(y1, y2)
  if w_I <= 0 or h_I <= 0:  # no overlap
      return 0.
  I = w_I * h_I
  U = w1 * h1 + w2 * h2 - I

  result = I / U

  return result

# %% [markdown]
# ## CODE

# %%
# Parameters
epochs = 150
batch_size = 8
img_size = 400
num_imgs = 5000
num_objects = 1

path = "/content/Dataset_Sequential/Dataset_Sequential/"

# Method Calls
x_train, y_train, x_val, y_val, x_test, y_test = data_loader(num_imgs, path)
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3000, 160000)
# (3000, 4)
# (1000, 160000)
# (1000, 4)
# (1000, 160000)
# (1000, 4)

# %% [markdown]
# ## BUILD THE NETWORK & TRAIN IT

# %%
# Build the model.
model = Sequential()
model.add(layers.Dense(400, activation='relu', input_dim=x_train.shape[-1]))
model.add(layers.Dense(200, activation='relu'))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(50, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(y_train.shape[-1]))

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate=0.01, rho=0.95, epsilon=1e-07), loss=tf.keras.losses.MeanSquaredError(), metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs = epochs, batch_size = batch_size, validation_data=(x_val, y_val), verbose=2)
# Out:
# Epoch 1/150
# 375/375 - 12s - loss: 0.0808 - accuracy: 0.5000 - val_loss: 0.0185 - val_accuracy: 0.6990 - 12s/epoch - 33ms/step
# Epoch 2/150
# 375/375 - 9s - loss: 0.0416 - accuracy: 0.5560 - val_loss: 0.0114 - val_accuracy: 0.6890 - 9s/epoch - 23ms/step
# Epoch 3/150
# 375/375 - 8s - loss: 0.0366 - accuracy: 0.5787 - val_loss: 0.0098 - val_accuracy: 0.7350 - 8s/epoch - 20ms/step
# Epoch 4/150
# 375/375 - 8s - loss: 0.0323 - accuracy: 0.6000 - val_loss: 0.0075 - val_accuracy: 0.7340 - 8s/epoch - 22ms/step
# Epoch 5/150
# 375/375 - 8s - loss: 0.0290 - accuracy: 0.6197 - val_loss: 0.0065 - val_accuracy: 0.8890 - 8s/epoch - 21ms/step
# Epoch 6/150
# 375/375 - 8s - loss: 0.0272 - accuracy: 0.6347 - val_loss: 0.0086 - val_accuracy: 0.7630 - 8s/epoch - 20ms/step
# Epoch 7/150
# 375/375 - 8s - loss: 0.0255 - accuracy: 0.6417 - val_loss: 0.0058 - val_accuracy: 0.8700 - 8s/epoch - 20ms/step
# Epoch 8/150
# 375/375 - 8s - loss: 0.0267 - accuracy: 0.6510 - val_loss: 0.0054 - val_accuracy: 0.8270 - 8s/epoch - 21ms/step
# Epoch 9/150
# 375/375 - 8s - loss: 0.0238 - accuracy: 0.6593 - val_loss: 0.0058 - val_accuracy: 0.8840 - 8s/epoch - 20ms/step
# Epoch 10/150
# 375/375 - 8s - loss: 0.0238 - accuracy: 0.6793 - val_loss: 0.0059 - val_accuracy: 0.8750 - 8s/epoch - 20ms/step
# Epoch 11/150
# 375/375 - 8s - loss: 0.0230 - accuracy: 0.6760 - val_loss: 0.0047 - val_accuracy: 0.9170 - 8s/epoch - 20ms/step
# Epoch 12/150
# 375/375 - 8s - loss: 0.0227 - accuracy: 0.6857 - val_loss: 0.0046 - val_accuracy: 0.9300 - 8s/epoch - 20ms/step
# Epoch 13/150
# 375/375 - 8s - loss: 0.0214 - accuracy: 0.6820 - val_loss: 0.0048 - val_accuracy: 0.8860 - 8s/epoch - 22ms/step
# Epoch 14/150
# 375/375 - 8s - loss: 0.0202 - accuracy: 0.6913 - val_loss: 0.0046 - val_accuracy: 0.9240 - 8s/epoch - 21ms/step
# Epoch 15/150
# 375/375 - 8s - loss: 0.0197 - accuracy: 0.6967 - val_loss: 0.0038 - val_accuracy: 0.9260 - 8s/epoch - 20ms/step
# Epoch 16/150
# 375/375 - 8s - loss: 0.0200 - accuracy: 0.6913 - val_loss: 0.0035 - val_accuracy: 0.9080 - 8s/epoch - 20ms/step
# Epoch 17/150
# 375/375 - 8s - loss: 0.0200 - accuracy: 0.7037 - val_loss: 0.0036 - val_accuracy: 0.9400 - 8s/epoch - 20ms/step
# Epoch 18/150
# 375/375 - 8s - loss: 0.0187 - accuracy: 0.7183 - val_loss: 0.0028 - val_accuracy: 0.9370 - 8s/epoch - 20ms/step
# Epoch 19/150
# 375/375 - 8s - loss: 0.0184 - accuracy: 0.7200 - val_loss: 0.0037 - val_accuracy: 0.9220 - 8s/epoch - 20ms/step
# Epoch 20/150
# 375/375 - 8s - loss: 0.0175 - accuracy: 0.7240 - val_loss: 0.0034 - val_accuracy: 0.9410 - 8s/epoch - 21ms/step
# Epoch 21/150
# 375/375 - 8s - loss: 0.0177 - accuracy: 0.7370 - val_loss: 0.0029 - val_accuracy: 0.9540 - 8s/epoch - 20ms/step
# Epoch 22/150
# 375/375 - 8s - loss: 0.0173 - accuracy: 0.7210 - val_loss: 0.0031 - val_accuracy: 0.9140 - 8s/epoch - 20ms/step
# Epoch 23/150
# 375/375 - 8s - loss: 0.0172 - accuracy: 0.7367 - val_loss: 0.0033 - val_accuracy: 0.9340 - 8s/epoch - 20ms/step
# Epoch 24/150
# 375/375 - 7s - loss: 0.0169 - accuracy: 0.7340 - val_loss: 0.0028 - val_accuracy: 0.9400 - 7s/epoch - 20ms/step
# Epoch 25/150
# 375/375 - 8s - loss: 0.0165 - accuracy: 0.7453 - val_loss: 0.0029 - val_accuracy: 0.9600 - 8s/epoch - 20ms/step
# Epoch 26/150
# 375/375 - 8s - loss: 0.0161 - accuracy: 0.7440 - val_loss: 0.0030 - val_accuracy: 0.9490 - 8s/epoch - 22ms/step
# Epoch 27/150
# 375/375 - 7s - loss: 0.0163 - accuracy: 0.7593 - val_loss: 0.0027 - val_accuracy: 0.9280 - 7s/epoch - 20ms/step
# Epoch 28/150
# 375/375 - 7s - loss: 0.0163 - accuracy: 0.7363 - val_loss: 0.0026 - val_accuracy: 0.9390 - 7s/epoch - 20ms/step
# Epoch 29/150
# 375/375 - 8s - loss: 0.0153 - accuracy: 0.7553 - val_loss: 0.0026 - val_accuracy: 0.9500 - 8s/epoch - 20ms/step
# Epoch 30/150
# 375/375 - 8s - loss: 0.0154 - accuracy: 0.7493 - val_loss: 0.0024 - val_accuracy: 0.9530 - 8s/epoch - 20ms/step
# Epoch 31/150
# 375/375 - 7s - loss: 0.0146 - accuracy: 0.7640 - val_loss: 0.0026 - val_accuracy: 0.9640 - 7s/epoch - 20ms/step
# Epoch 32/150
# 375/375 - 8s - loss: 0.0146 - accuracy: 0.7613 - val_loss: 0.0028 - val_accuracy: 0.9740 - 8s/epoch - 22ms/step
# Epoch 33/150
# 375/375 - 8s - loss: 0.0143 - accuracy: 0.7653 - val_loss: 0.0024 - val_accuracy: 0.9540 - 8s/epoch - 20ms/step
# Epoch 34/150
# 375/375 - 8s - loss: 0.0145 - accuracy: 0.7697 - val_loss: 0.0023 - val_accuracy: 0.9360 - 8s/epoch - 20ms/step
# Epoch 35/150
# 375/375 - 7s - loss: 0.0137 - accuracy: 0.7687 - val_loss: 0.0022 - val_accuracy: 0.9770 - 7s/epoch - 20ms/step
# Epoch 36/150
# 375/375 - 7s - loss: 0.0144 - accuracy: 0.7790 - val_loss: 0.0019 - val_accuracy: 0.9570 - 7s/epoch - 20ms/step
# Epoch 37/150
# 375/375 - 8s - loss: 0.0135 - accuracy: 0.7857 - val_loss: 0.0026 - val_accuracy: 0.9440 - 8s/epoch - 20ms/step
# Epoch 38/150
# 375/375 - 8s - loss: 0.0132 - accuracy: 0.7813 - val_loss: 0.0019 - val_accuracy: 0.9620 - 8s/epoch - 21ms/step
# Epoch 39/150
# 375/375 - 8s - loss: 0.0132 - accuracy: 0.7690 - val_loss: 0.0019 - val_accuracy: 0.9150 - 8s/epoch - 21ms/step
# Epoch 40/150
# 375/375 - 8s - loss: 0.0131 - accuracy: 0.7753 - val_loss: 0.0017 - val_accuracy: 0.9580 - 8s/epoch - 20ms/step
# Epoch 41/150
# 375/375 - 8s - loss: 0.0128 - accuracy: 0.7850 - val_loss: 0.0020 - val_accuracy: 0.9600 - 8s/epoch - 20ms/step
# Epoch 42/150
# 375/375 - 8s - loss: 0.0127 - accuracy: 0.7903 - val_loss: 0.0019 - val_accuracy: 0.9680 - 8s/epoch - 20ms/step
# Epoch 43/150
# 375/375 - 8s - loss: 0.0127 - accuracy: 0.8043 - val_loss: 0.0018 - val_accuracy: 0.9770 - 8s/epoch - 20ms/step
# Epoch 44/150
# 375/375 - 8s - loss: 0.0120 - accuracy: 0.7943 - val_loss: 0.0023 - val_accuracy: 0.9590 - 8s/epoch - 20ms/step
# Epoch 45/150
# 375/375 - 8s - loss: 0.0121 - accuracy: 0.7990 - val_loss: 0.0018 - val_accuracy: 0.9660 - 8s/epoch - 21ms/step
# Epoch 46/150
# 375/375 - 8s - loss: 0.0119 - accuracy: 0.7920 - val_loss: 0.0020 - val_accuracy: 0.9720 - 8s/epoch - 20ms/step
# Epoch 47/150
# 375/375 - 8s - loss: 0.0120 - accuracy: 0.8077 - val_loss: 0.0018 - val_accuracy: 0.9750 - 8s/epoch - 20ms/step
# Epoch 48/150
# 375/375 - 8s - loss: 0.0114 - accuracy: 0.8077 - val_loss: 0.0018 - val_accuracy: 0.9700 - 8s/epoch - 20ms/step
# Epoch 49/150
# 375/375 - 8s - loss: 0.0118 - accuracy: 0.8050 - val_loss: 0.0021 - val_accuracy: 0.9800 - 8s/epoch - 20ms/step
# Epoch 50/150
# 375/375 - 8s - loss: 0.0118 - accuracy: 0.8050 - val_loss: 0.0014 - val_accuracy: 0.9680 - 8s/epoch - 20ms/step
# Epoch 51/150
# 375/375 - 9s - loss: 0.0116 - accuracy: 0.8200 - val_loss: 0.0018 - val_accuracy: 0.9680 - 9s/epoch - 23ms/step
# Epoch 52/150
# 375/375 - 8s - loss: 0.0109 - accuracy: 0.8117 - val_loss: 0.0014 - val_accuracy: 0.9920 - 8s/epoch - 20ms/step
# Epoch 53/150
# 375/375 - 8s - loss: 0.0112 - accuracy: 0.8043 - val_loss: 0.0018 - val_accuracy: 0.9640 - 8s/epoch - 20ms/step
# Epoch 54/150
# 375/375 - 8s - loss: 0.0116 - accuracy: 0.8060 - val_loss: 0.0022 - val_accuracy: 0.9740 - 8s/epoch - 20ms/step
# Epoch 55/150
# 375/375 - 8s - loss: 0.0108 - accuracy: 0.8140 - val_loss: 0.0017 - val_accuracy: 0.9630 - 8s/epoch - 20ms/step
# Epoch 56/150
# 375/375 - 8s - loss: 0.0105 - accuracy: 0.8253 - val_loss: 0.0023 - val_accuracy: 0.9670 - 8s/epoch - 20ms/step
# Epoch 57/150
# 375/375 - 8s - loss: 0.0104 - accuracy: 0.8253 - val_loss: 0.0020 - val_accuracy: 0.9690 - 8s/epoch - 22ms/step
# Epoch 58/150
# 375/375 - 8s - loss: 0.0104 - accuracy: 0.8177 - val_loss: 0.0015 - val_accuracy: 0.9900 - 8s/epoch - 21ms/step
# Epoch 59/150
# 375/375 - 8s - loss: 0.0103 - accuracy: 0.8247 - val_loss: 0.0016 - val_accuracy: 0.9660 - 8s/epoch - 20ms/step
# Epoch 60/150
# 375/375 - 8s - loss: 0.0103 - accuracy: 0.8307 - val_loss: 0.0014 - val_accuracy: 0.9700 - 8s/epoch - 20ms/step
# Epoch 61/150
# 375/375 - 8s - loss: 0.0104 - accuracy: 0.8237 - val_loss: 0.0012 - val_accuracy: 0.9760 - 8s/epoch - 20ms/step
# Epoch 62/150
# 375/375 - 8s - loss: 0.0104 - accuracy: 0.8207 - val_loss: 0.0014 - val_accuracy: 0.9800 - 8s/epoch - 20ms/step
# Epoch 63/150
# 375/375 - 8s - loss: 0.0095 - accuracy: 0.8333 - val_loss: 0.0017 - val_accuracy: 0.9860 - 8s/epoch - 22ms/step
# Epoch 64/150
# 375/375 - 8s - loss: 0.0096 - accuracy: 0.8340 - val_loss: 0.0014 - val_accuracy: 0.9670 - 8s/epoch - 21ms/step
# Epoch 65/150
# 375/375 - 8s - loss: 0.0098 - accuracy: 0.8350 - val_loss: 0.0015 - val_accuracy: 0.9780 - 8s/epoch - 20ms/step
# Epoch 66/150
# 375/375 - 8s - loss: 0.0096 - accuracy: 0.8420 - val_loss: 0.0013 - val_accuracy: 0.9710 - 8s/epoch - 20ms/step
# Epoch 67/150
# 375/375 - 8s - loss: 0.0101 - accuracy: 0.8410 - val_loss: 0.0017 - val_accuracy: 0.9740 - 8s/epoch - 20ms/step
# Epoch 68/150
# 375/375 - 8s - loss: 0.0099 - accuracy: 0.8413 - val_loss: 0.0013 - val_accuracy: 0.9650 - 8s/epoch - 20ms/step
# Epoch 69/150
# 375/375 - 8s - loss: 0.0093 - accuracy: 0.8510 - val_loss: 0.0021 - val_accuracy: 0.9740 - 8s/epoch - 22ms/step
# Epoch 70/150
# 375/375 - 8s - loss: 0.0096 - accuracy: 0.8367 - val_loss: 0.0014 - val_accuracy: 0.9590 - 8s/epoch - 21ms/step
# Epoch 71/150
# 375/375 - 8s - loss: 0.0094 - accuracy: 0.8363 - val_loss: 0.0015 - val_accuracy: 0.9890 - 8s/epoch - 20ms/step
# Epoch 72/150
# 375/375 - 8s - loss: 0.0090 - accuracy: 0.8507 - val_loss: 0.0014 - val_accuracy: 0.9760 - 8s/epoch - 20ms/step
# Epoch 73/150
# 375/375 - 8s - loss: 0.0093 - accuracy: 0.8450 - val_loss: 0.0012 - val_accuracy: 0.9780 - 8s/epoch - 20ms/step
# Epoch 74/150
# 375/375 - 8s - loss: 0.0092 - accuracy: 0.8440 - val_loss: 9.3108e-04 - val_accuracy: 0.9670 - 8s/epoch - 20ms/step
# Epoch 75/150
# 375/375 - 8s - loss: 0.0090 - accuracy: 0.8580 - val_loss: 0.0012 - val_accuracy: 0.9810 - 8s/epoch - 21ms/step
# Epoch 76/150
# 375/375 - 8s - loss: 0.0085 - accuracy: 0.8527 - val_loss: 0.0013 - val_accuracy: 0.9940 - 8s/epoch - 21ms/step
# Epoch 77/150
# 375/375 - 8s - loss: 0.0083 - accuracy: 0.8567 - val_loss: 0.0010 - val_accuracy: 0.9820 - 8s/epoch - 20ms/step
# Epoch 78/150
# 375/375 - 8s - loss: 0.0088 - accuracy: 0.8527 - val_loss: 0.0012 - val_accuracy: 0.9770 - 8s/epoch - 20ms/step
# Epoch 79/150
# 375/375 - 8s - loss: 0.0084 - accuracy: 0.8627 - val_loss: 0.0014 - val_accuracy: 0.9560 - 8s/epoch - 20ms/step
# Epoch 80/150
# 375/375 - 8s - loss: 0.0089 - accuracy: 0.8580 - val_loss: 0.0013 - val_accuracy: 0.9920 - 8s/epoch - 20ms/step
# Epoch 81/150
# 375/375 - 8s - loss: 0.0080 - accuracy: 0.8607 - val_loss: 0.0013 - val_accuracy: 0.9930 - 8s/epoch - 20ms/step
# Epoch 82/150
# 375/375 - 8s - loss: 0.0081 - accuracy: 0.8583 - val_loss: 0.0013 - val_accuracy: 0.9670 - 8s/epoch - 21ms/step
# Epoch 83/150
# 375/375 - 8s - loss: 0.0082 - accuracy: 0.8553 - val_loss: 0.0012 - val_accuracy: 0.9890 - 8s/epoch - 20ms/step
# Epoch 84/150
# 375/375 - 8s - loss: 0.0079 - accuracy: 0.8477 - val_loss: 0.0012 - val_accuracy: 0.9950 - 8s/epoch - 20ms/step
# Epoch 85/150
# 375/375 - 7s - loss: 0.0081 - accuracy: 0.8567 - val_loss: 0.0013 - val_accuracy: 0.9850 - 7s/epoch - 20ms/step
# Epoch 86/150
# 375/375 - 7s - loss: 0.0081 - accuracy: 0.8693 - val_loss: 0.0010 - val_accuracy: 0.9970 - 7s/epoch - 20ms/step
# Epoch 87/150
# 375/375 - 8s - loss: 0.0078 - accuracy: 0.8603 - val_loss: 0.0013 - val_accuracy: 0.9870 - 8s/epoch - 22ms/step
# Epoch 88/150
# 375/375 - 8s - loss: 0.0080 - accuracy: 0.8590 - val_loss: 0.0017 - val_accuracy: 0.9780 - 8s/epoch - 21ms/step
# Epoch 89/150
# 375/375 - 7s - loss: 0.0077 - accuracy: 0.8667 - val_loss: 0.0011 - val_accuracy: 0.9660 - 7s/epoch - 20ms/step
# Epoch 90/150
# 375/375 - 7s - loss: 0.0079 - accuracy: 0.8617 - val_loss: 0.0011 - val_accuracy: 0.9770 - 7s/epoch - 20ms/step
# Epoch 91/150
# 375/375 - 7s - loss: 0.0075 - accuracy: 0.8737 - val_loss: 0.0012 - val_accuracy: 0.9740 - 7s/epoch - 20ms/step
# Epoch 92/150
# 375/375 - 7s - loss: 0.0076 - accuracy: 0.8647 - val_loss: 0.0014 - val_accuracy: 0.9710 - 7s/epoch - 20ms/step
# Epoch 93/150
# 375/375 - 7s - loss: 0.0073 - accuracy: 0.8647 - val_loss: 9.2926e-04 - val_accuracy: 0.9760 - 7s/epoch - 20ms/step
# Epoch 94/150
# 375/375 - 8s - loss: 0.0072 - accuracy: 0.8767 - val_loss: 0.0011 - val_accuracy: 0.9910 - 8s/epoch - 20ms/step
# Epoch 95/150
# 375/375 - 7s - loss: 0.0075 - accuracy: 0.8760 - val_loss: 8.7609e-04 - val_accuracy: 0.9910 - 7s/epoch - 20ms/step
# Epoch 96/150
# 375/375 - 7s - loss: 0.0073 - accuracy: 0.8720 - val_loss: 0.0010 - val_accuracy: 0.9920 - 7s/epoch - 20ms/step
# Epoch 97/150
# 375/375 - 7s - loss: 0.0073 - accuracy: 0.8637 - val_loss: 8.8390e-04 - val_accuracy: 0.9640 - 7s/epoch - 20ms/step
# Epoch 98/150
# 375/375 - 7s - loss: 0.0071 - accuracy: 0.8943 - val_loss: 0.0010 - val_accuracy: 0.9900 - 7s/epoch - 20ms/step
# Epoch 99/150
# 375/375 - 7s - loss: 0.0073 - accuracy: 0.8773 - val_loss: 9.7487e-04 - val_accuracy: 0.9910 - 7s/epoch - 20ms/step
# Epoch 100/150
# 375/375 - 8s - loss: 0.0069 - accuracy: 0.8823 - val_loss: 7.9963e-04 - val_accuracy: 0.9770 - 8s/epoch - 21ms/step
# Epoch 101/150
# 375/375 - 8s - loss: 0.0070 - accuracy: 0.8787 - val_loss: 8.2091e-04 - val_accuracy: 0.9930 - 8s/epoch - 20ms/step
# Epoch 102/150
# 375/375 - 7s - loss: 0.0069 - accuracy: 0.8680 - val_loss: 0.0011 - val_accuracy: 0.9960 - 7s/epoch - 20ms/step
# Epoch 103/150
# 375/375 - 7s - loss: 0.0068 - accuracy: 0.8933 - val_loss: 9.9971e-04 - val_accuracy: 0.9990 - 7s/epoch - 20ms/step
# Epoch 104/150
# 375/375 - 7s - loss: 0.0070 - accuracy: 0.8800 - val_loss: 8.7069e-04 - val_accuracy: 0.9810 - 7s/epoch - 20ms/step
# Epoch 105/150
# 375/375 - 8s - loss: 0.0068 - accuracy: 0.8843 - val_loss: 7.8572e-04 - val_accuracy: 0.9960 - 8s/epoch - 20ms/step
# Epoch 106/150
# 375/375 - 8s - loss: 0.0071 - accuracy: 0.8817 - val_loss: 8.5361e-04 - val_accuracy: 0.9810 - 8s/epoch - 21ms/step
# Epoch 107/150
# 375/375 - 8s - loss: 0.0067 - accuracy: 0.8863 - val_loss: 7.8189e-04 - val_accuracy: 0.9920 - 8s/epoch - 21ms/step
# Epoch 108/150
# 375/375 - 8s - loss: 0.0068 - accuracy: 0.8783 - val_loss: 7.9198e-04 - val_accuracy: 0.9750 - 8s/epoch - 20ms/step
# Epoch 109/150
# 375/375 - 8s - loss: 0.0067 - accuracy: 0.8860 - val_loss: 8.1960e-04 - val_accuracy: 0.9880 - 8s/epoch - 20ms/step
# Epoch 110/150
# 375/375 - 8s - loss: 0.0067 - accuracy: 0.8927 - val_loss: 9.8180e-04 - val_accuracy: 0.9980 - 8s/epoch - 20ms/step
# Epoch 111/150
# 375/375 - 8s - loss: 0.0068 - accuracy: 0.8863 - val_loss: 9.8456e-04 - val_accuracy: 0.9900 - 8s/epoch - 20ms/step
# Epoch 112/150
# 375/375 - 8s - loss: 0.0065 - accuracy: 0.8907 - val_loss: 9.1780e-04 - val_accuracy: 0.9960 - 8s/epoch - 22ms/step
# Epoch 113/150
# 375/375 - 8s - loss: 0.0064 - accuracy: 0.8880 - val_loss: 9.0182e-04 - val_accuracy: 0.9970 - 8s/epoch - 22ms/step
# Epoch 114/150
# 375/375 - 8s - loss: 0.0064 - accuracy: 0.8930 - val_loss: 7.5359e-04 - val_accuracy: 0.9840 - 8s/epoch - 20ms/step
# Epoch 115/150
# 375/375 - 8s - loss: 0.0067 - accuracy: 0.8880 - val_loss: 6.7367e-04 - val_accuracy: 0.9910 - 8s/epoch - 20ms/step
# Epoch 116/150
# 375/375 - 8s - loss: 0.0063 - accuracy: 0.8940 - val_loss: 0.0011 - val_accuracy: 0.9890 - 8s/epoch - 20ms/step
# Epoch 117/150
# 375/375 - 8s - loss: 0.0062 - accuracy: 0.8970 - val_loss: 8.0376e-04 - val_accuracy: 0.9860 - 8s/epoch - 20ms/step
# Epoch 118/150
# 375/375 - 8s - loss: 0.0061 - accuracy: 0.9003 - val_loss: 8.1820e-04 - val_accuracy: 0.9800 - 8s/epoch - 23ms/step
# Epoch 119/150
# 375/375 - 8s - loss: 0.0061 - accuracy: 0.9113 - val_loss: 0.0010 - val_accuracy: 0.9870 - 8s/epoch - 20ms/step
# Epoch 120/150
# 375/375 - 8s - loss: 0.0061 - accuracy: 0.8930 - val_loss: 6.7623e-04 - val_accuracy: 0.9920 - 8s/epoch - 20ms/step
# Epoch 121/150
# 375/375 - 8s - loss: 0.0063 - accuracy: 0.8943 - val_loss: 7.2986e-04 - val_accuracy: 0.9900 - 8s/epoch - 20ms/step
# Epoch 122/150
# 375/375 - 8s - loss: 0.0061 - accuracy: 0.9003 - val_loss: 7.6185e-04 - val_accuracy: 0.9960 - 8s/epoch - 20ms/step
# Epoch 123/150
# 375/375 - 7s - loss: 0.0061 - accuracy: 0.9010 - val_loss: 8.0203e-04 - val_accuracy: 0.9980 - 7s/epoch - 20ms/step
# Epoch 124/150
# 375/375 - 8s - loss: 0.0058 - accuracy: 0.8993 - val_loss: 8.6537e-04 - val_accuracy: 0.9920 - 8s/epoch - 21ms/step
# Epoch 125/150
# 375/375 - 8s - loss: 0.0059 - accuracy: 0.9143 - val_loss: 9.5651e-04 - val_accuracy: 0.9950 - 8s/epoch - 20ms/step
# Epoch 126/150
# 375/375 - 7s - loss: 0.0060 - accuracy: 0.9213 - val_loss: 9.7182e-04 - val_accuracy: 0.9910 - 7s/epoch - 20ms/step
# Epoch 127/150
# 375/375 - 7s - loss: 0.0060 - accuracy: 0.8953 - val_loss: 7.3678e-04 - val_accuracy: 0.9960 - 7s/epoch - 20ms/step
# Epoch 128/150
# 375/375 - 7s - loss: 0.0057 - accuracy: 0.9010 - val_loss: 5.6147e-04 - val_accuracy: 0.9970 - 7s/epoch - 20ms/step
# Epoch 129/150
# 375/375 - 7s - loss: 0.0057 - accuracy: 0.9067 - val_loss: 7.9605e-04 - val_accuracy: 0.9970 - 7s/epoch - 20ms/step
# Epoch 130/150
# 375/375 - 7s - loss: 0.0059 - accuracy: 0.9097 - val_loss: 7.6093e-04 - val_accuracy: 0.9690 - 7s/epoch - 20ms/step
# Epoch 131/150
# 375/375 - 8s - loss: 0.0057 - accuracy: 0.9240 - val_loss: 6.0957e-04 - val_accuracy: 0.9970 - 8s/epoch - 20ms/step
# Epoch 132/150
# 375/375 - 7s - loss: 0.0057 - accuracy: 0.9090 - val_loss: 0.0011 - val_accuracy: 0.9820 - 7s/epoch - 20ms/step
# Epoch 133/150
# 375/375 - 7s - loss: 0.0059 - accuracy: 0.9040 - val_loss: 7.2935e-04 - val_accuracy: 0.9870 - 7s/epoch - 20ms/step
# Epoch 134/150
# 375/375 - 7s - loss: 0.0056 - accuracy: 0.9173 - val_loss: 8.0958e-04 - val_accuracy: 0.9950 - 7s/epoch - 20ms/step
# Epoch 135/150
# 375/375 - 7s - loss: 0.0054 - accuracy: 0.9127 - val_loss: 0.0012 - val_accuracy: 0.9970 - 7s/epoch - 20ms/step
# Epoch 136/150
# 375/375 - 8s - loss: 0.0053 - accuracy: 0.9110 - val_loss: 6.6216e-04 - val_accuracy: 0.9970 - 8s/epoch - 20ms/step
# Epoch 137/150
# 375/375 - 8s - loss: 0.0053 - accuracy: 0.9140 - val_loss: 6.5165e-04 - val_accuracy: 0.9910 - 8s/epoch - 21ms/step
# Epoch 138/150
# 375/375 - 8s - loss: 0.0057 - accuracy: 0.9093 - val_loss: 7.4688e-04 - val_accuracy: 0.9920 - 8s/epoch - 21ms/step
# Epoch 139/150
# 375/375 - 8s - loss: 0.0053 - accuracy: 0.9097 - val_loss: 7.0954e-04 - val_accuracy: 0.9890 - 8s/epoch - 20ms/step
# Epoch 140/150
# 375/375 - 8s - loss: 0.0053 - accuracy: 0.9180 - val_loss: 5.7950e-04 - val_accuracy: 0.9980 - 8s/epoch - 20ms/step
# Epoch 141/150
# 375/375 - 8s - loss: 0.0053 - accuracy: 0.9127 - val_loss: 7.2281e-04 - val_accuracy: 0.9950 - 8s/epoch - 20ms/step
# Epoch 142/150
# 375/375 - 8s - loss: 0.0051 - accuracy: 0.9187 - val_loss: 5.0689e-04 - val_accuracy: 0.9940 - 8s/epoch - 22ms/step
# Epoch 143/150
# 375/375 - 8s - loss: 0.0055 - accuracy: 0.9167 - val_loss: 6.4064e-04 - val_accuracy: 0.9960 - 8s/epoch - 21ms/step
# Epoch 144/150
# 375/375 - 8s - loss: 0.0054 - accuracy: 0.9190 - val_loss: 7.2479e-04 - val_accuracy: 0.9960 - 8s/epoch - 20ms/step
# Epoch 145/150
# 375/375 - 8s - loss: 0.0053 - accuracy: 0.9273 - val_loss: 9.7602e-04 - val_accuracy: 0.9970 - 8s/epoch - 20ms/step
# Epoch 146/150
# 375/375 - 8s - loss: 0.0055 - accuracy: 0.9153 - val_loss: 6.0183e-04 - val_accuracy: 0.9950 - 8s/epoch - 20ms/step
# Epoch 147/150
# 375/375 - 8s - loss: 0.0052 - accuracy: 0.9263 - val_loss: 7.2954e-04 - val_accuracy: 0.9890 - 8s/epoch - 20ms/step
# Epoch 148/150
# 375/375 - 8s - loss: 0.0052 - accuracy: 0.9240 - val_loss: 6.0252e-04 - val_accuracy: 0.9950 - 8s/epoch - 20ms/step
# Epoch 149/150
# 375/375 - 9s - loss: 0.0053 - accuracy: 0.9303 - val_loss: 6.5331e-04 - val_accuracy: 0.9920 - 9s/epoch - 23ms/step
# Epoch 150/150
# 375/375 - 8s - loss: 0.0051 - accuracy: 0.9290 - val_loss: 5.5817e-04 - val_accuracy: 0.9910 - 8s/epoch - 20ms/step

# %%
# Loss
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='Training loss') #blue dots
plt.plot(epochs, val_loss, 'g', label='Validation loss') #blue line
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'b', label='Training accuracy') #blue dots
plt.plot(epochs, val_accuracy, 'g', label='Validation accuracy') #blue line
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## EVALUATE THE RESULTS

# %%
# Predict with the testing data. 
predictions = model.predict(x_test)
# Out:
# 32/32 [==============================] - 0s 12ms/step

# %%
# Resize the data. 
predictions *= img_size
predictions = predictions.reshape(len(predictions), num_objects, -1)

# %%
y_test *= img_size

# Calculate the real accuracy of the model -  With the mean IOU
Accomulated_IOU = 0.
for predicted_value, real_value in zip(predictions.reshape(-1, 4), y_test.reshape(-1, 4)):
  Accomulated_IOU += IOU(predicted_value, real_value)
mean_IOU = Accomulated_IOU / len(predictions)
print("Actual accuracy level of the system: ", mean_IOU)
# Out:
# Actual accuracy level of the system:  0.5040869654983103

# %%
# Show a few images and predicted bounding boxes from the test dataset. 
x_test = x_test.reshape(len(x_test), img_size, img_size)
y_test = y_test.reshape(len(y_test), num_objects, 4)

plt.figure(figsize=(12, 3))
for i_subplot in range(1, 5):
    plt.subplot(1, 4, i_subplot)
    i = np.random.randint(len(x_test))
    plt.imshow(x_test[i], cmap=plt.cm.get_cmap('Greys').reversed(), interpolation='none', origin='lower', extent=[0, img_size, 0, img_size])
    for pred_bbox, exp_bbox in zip(predictions[i], y_test[i]):
        plt.gca().add_patch(matplotlib.patches.Rectangle((pred_bbox[0], pred_bbox[3]), pred_bbox[2]-pred_bbox[0], pred_bbox[1] - pred_bbox[3], ec='r', fc='none'))
        plt.annotate('IOU: {:.2f}'.format(IOU(pred_bbox, exp_bbox)), (pred_bbox[0], pred_bbox[3] + 40), color='r')
        
# plt.savefig('plots/bw-single-rectangle_prediction.png', dpi=300)

# %% [markdown]
# ## SAVE THE MODEL

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 400)               64000400
#
#  dense_1 (Dense)             (None, 200)               80200
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  dense_3 (Dense)             (None, 50)                5050
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_4 (Dense)             (None, 4)                 204
#
# =================================================================
# Total params: 64,105,954
# Trainable params: 64,105,954
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
from IPython.display import display, Image
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
display(Image(filename='model_plot.png'))

# %%
model.save('basic_model.hdf5')
